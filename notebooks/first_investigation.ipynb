# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os
current_dir = os.getcwd()

# %%
population = pd.read_csv('../data/population.csv')
population.head()
# Out:
# /var/folders/m4/rl8q4_8s3531vrprrghc32pm0000gn/T/ipykernel_34520/2507705166.py:1: DtypeWarning: Columns (1) have mixed types. Specify dtype option on import or set low_memory=False.
#   population = pd.read_csv('../data/population.csv')
#   NIVGEO CODGEO                   LIBGEO  MOCO  AGEQ80_17  SEXE  NB
# 0    COM   1001  L'Abergement-Clémenciat    11          0     1  15
# 1    COM   1001  L'Abergement-Clémenciat    11          0     2  15
# 2    COM   1001  L'Abergement-Clémenciat    11          5     1  20
# 3    COM   1001  L'Abergement-Clémenciat    11          5     2  20
# 4    COM   1001  L'Abergement-Clémenciat    11         10     1  20

# %%
# DF summary with info about amount of unique and missing values and a type of the column of the dataframe

def summary(df):
    tab = pd.DataFrame(index = df.columns, columns = ['nb_unique_values','nb_missing_values','type'])
    tab.loc[:,'nb_unique_values'] = df.nunique().values
    tab.loc[:,'nb_missing_values'] = df.isna().sum().values
    tab.loc[:, 'type'] = df.dtypes.values
    return tab

summary(population)
# Out:
#           nb_unique_values nb_missing_values    type
# NIVGEO                   1                 0  object
# CODGEO               35870                 0  object
# LIBGEO               33452                 0  object
# MOCO                     7                 0   int64
# AGEQ80_17               17                 0   int64
# SEXE                     2                 0   int64
# NB                    2953                 0   int64

# %%
os.getcwd()

salary = pd.read_csv('../data/net_salary_per_town_categories.csv')
salary.head()
# Out:
#   CODGEO             LIBGEO  SNHM14  SNHMC14  SNHMP14  SNHME14  SNHMO14  \
# 0  01004  Ambérieu-en-Bugey    13.7     24.2     15.5     10.3     11.2
# 1  01007           Ambronay    13.5     22.1     14.7     10.7     11.4
# 2  01014             Arbent    13.5     27.6     15.6     11.1     11.1
# 3  01024           Attignat    12.9     21.8     14.1     11.0     11.3
# 4  01025      Bâgé-la-Ville    13.0     22.8     14.1     10.5     11.1
#
#    SNHMF14  SNHMFC14  SNHMFP14  ...  SNHMHO14  SNHM1814  SNHM2614  SNHM5014  \
# 0     11.6      19.1      13.2  ...      11.6      10.5      13.7      16.1
# 1     11.9      19.0      13.3  ...      11.7       9.8      13.8      14.6
# 2     10.9      19.5      11.7  ...      11.8       9.3      13.3      16.0
# 3     11.4      19.0      13.0  ...      11.6       9.6      12.9      14.2
# 4     11.6      19.4      13.6  ...      11.4       9.4      12.8      15.2
#
#    SNHMF1814  SNHMF2614  SNHMF5014  SNHMH1814  SNHMH2614  SNHMH5014
# 0        9.7       11.8       12.5       11.0       14.9       18.6
# 1        9.2       12.2       12.5       10.2       14.9       16.4
# 2        8.9       10.6       12.5        9.6       15.1       18.6
# 3        9.3       11.4       12.2        9.7       13.8       15.9
# 4        9.0       11.8       12.3        9.7       13.4       16.9
#
# [5 rows x 26 columns]

# %%
display(summary(salary))
display(salary.describe())
# Out:
#           nb_unique_values nb_missing_values     type
# CODGEO                5136                 0   object
# LIBGEO                5085                 0   object
# SNHM14                 167                 0  float64
# SNHMC14                202                 0  float64
# SNHMP14                 99                 0  float64
# SNHME14                 69                 0  float64
# SNHMO14                 97                 0  float64
# SNHMF14                129                 0  float64
# SNHMFC14               175                 0  float64
# SNHMFP14                74                 0  float64
# SNHMFE14                59                 0  float64
# SNHMFO14               103                 0  float64
# SNHMH14                200                 0  float64
# SNHMHC14               228                 0  float64
# SNHMHP14               122                 0  float64
# SNHMHE14                98                 0  float64
# SNHMHO14                96                 0  float64
# SNHM1814                62                 0  float64
# SNHM2614               160                 0  float64
# SNHM5014               224                 0  float64
# SNHMF1814               43                 0  float64
# SNHMF2614              128                 0  float64
# SNHMF5014              154                 0  float64
# SNHMH1814               72                 0  float64
# SNHMH2614              192                 0  float64
# SNHMH5014              266                 0  float64
#             SNHM14      SNHMC14      SNHMP14      SNHME14      SNHMO14  \
# count  5136.000000  5136.000000  5136.000000  5136.000000  5136.000000
# mean     13.706386    23.703836    14.575876    10.564505    11.235650
# std       2.559329     2.836183     1.490110     0.811775     1.221755
# min      10.200000    16.000000    11.600000     8.700000     8.300000
# 25%      12.100000    21.900000    13.800000    10.000000    10.600000
# 50%      13.000000    23.200000    14.400000    10.400000    11.000000
# 75%      14.400000    24.900000    15.100000    10.900000    11.600000
# max      43.300000    51.500000    54.600000    17.500000    46.300000
#
#            SNHMF14     SNHMFC14     SNHMFP14     SNHMFE14     SNHMFO14  ...  \
# count  5136.000000  5136.000000  5136.000000  5136.000000  5136.000000  ...
# mean     12.038026    20.220502    13.274260    10.308879     9.827161  ...
# std       1.787995     2.327550     0.990166     0.747563     1.104684  ...
# min       9.300000    12.000000    10.600000     8.700000     6.100000  ...
# 25%      10.900000    18.800000    12.600000     9.800000     9.200000  ...
# 50%      11.500000    20.000000    13.100000    10.100000     9.700000  ...
# 75%      12.700000    21.400000    13.800000    10.600000    10.200000  ...
# max      26.700000    35.500000    19.000000    16.100000    28.100000  ...
#
#           SNHMHO14     SNHM1814     SNHM2614    SNHM5014    SNHMF1814  \
# count  5136.000000  5136.000000  5136.000000  5136.00000  5136.000000
# mean     11.498189     9.549766    13.495444    15.87722     9.161565
# std       1.289598     0.997444     2.363144     3.58586     0.453023
# min       8.900000     7.900000     9.700000    10.50000     7.500000
# 25%      10.800000     9.200000    12.000000    13.70000     8.900000
# 50%      11.300000     9.500000    12.900000    15.00000     9.100000
# 75%      11.900000     9.700000    14.300000    16.90000     9.400000
# max      53.200000    60.600000    38.100000    56.90000    12.000000
#
#          SNHMF2614    SNHMF5014    SNHMH1814    SNHMH2614    SNHMH5014
# count  5136.000000  5136.000000  5136.000000  5136.000000  5136.000000
# mean     12.055160    13.174143     9.820872    14.485981    17.679809
# std       1.825306     2.249391     1.539949     2.852490     4.530257
# min       9.100000     9.500000     7.800000     9.600000    10.800000
# 25%      10.900000    11.700000     9.400000    12.700000    14.900000
# 50%      11.600000    12.600000     9.700000    13.800000    16.600000
# 75%      12.700000    14.000000    10.000000    15.500000    19.000000
# max      26.600000    31.000000    93.300000    45.400000    68.600000
#
# [8 rows x 24 columns]
